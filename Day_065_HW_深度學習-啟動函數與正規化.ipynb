# %% [markdown]
# # 作業
# * 選擇分類資料集(右下)-螺旋雙臂 - 交錯六群，限定特徵只能使用前兩個，隱藏層 2 層滿 (共 8 * 2 =16 個神經元)，
#   遞迴次數只允許跑到500次，但可以自由調整 批次大小、學習速率、啟動函數、正規化選項與參數
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數

# %% [markdown]
# ## Test Loss: 0.081
# * Learning rate:0.3
# * Acvtivation:ReLU
# * Batch size:20
# * No Regularization rate

# %%
import matplotlib.pyplot as plt

img = plt.imread('RELU.jpg')
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Test Loss: 0.031
# * Learning rate:0.3
# * Acvtivation:ReLU
# * Batch size:20
# * Regularization rate:0.001

# %%
img = plt.imread('RELU+regularization.jpg')
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Test Loss: 0.015
# * Learning rate:0.1
# * Acvtivation:ReLU
# * Batch size:20
# * Regularization rate:0.001

# %%
img = plt.imread('RELU+learning0.1.jpg')
plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %% [markdown]
# ## 筆記
# * 測試最佳結果：Batch Size 20，Learning rate為 0.1，啟動函數為 ReLU，Regularization rate為0.001，最終 Test Loss 為 0.015
# * 可以從上面三次測試得到:Batch size跟啟動函數固定的情況下，使用Regularization rate比沒使用來的好，以及learning rate從0.3降低到0.1效果也會更好
