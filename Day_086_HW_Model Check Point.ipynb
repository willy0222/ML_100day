# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')

# Disable GPU
# os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
# 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import ModelCheckpoint


model_ckpt = ModelCheckpoint(filepath = "./tmp.h5",
                            monitor = "val_loss",
                            save_best_only = True)

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

model.save("final_model.h5")
model.save_weights("model_weights.h5")
# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

pred_final = model.predict(x_test)
# Load back
model = keras.models.load_model("./tmp.h5")
pred_loadback = model.predict(x_test)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 3s 12ms/step - loss: 1.8679 - accuracy: 0.3594 - val_loss: 1.8054 - val_accuracy: 0.3659
# Epoch 2/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.5460 - accuracy: 0.4584 - val_loss: 1.6583 - val_accuracy: 0.4063
# Epoch 3/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.4460 - accuracy: 0.4940 - val_loss: 1.5660 - val_accuracy: 0.4488
# Epoch 4/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.3722 - accuracy: 0.5193 - val_loss: 1.4979 - val_accuracy: 0.4685
# Epoch 5/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.3179 - accuracy: 0.5375 - val_loss: 1.5674 - val_accuracy: 0.4510
# Epoch 6/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.2679 - accuracy: 0.5561 - val_loss: 1.4738 - val_accuracy: 0.4827
# Epoch 7/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.2223 - accuracy: 0.5734 - val_loss: 1.5023 - val_accuracy: 0.4601
# Epoch 8/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.1813 - accuracy: 0.5892 - val_loss: 1.4430 - val_accuracy: 0.4920
# Epoch 9/50
# 196/196 [==============================] - 3s 13ms/step - loss: 1.1385 - accuracy: 0.6032 - val_loss: 1.4704 - val_accuracy: 0.4947
# Epoch 10/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.1037 - accuracy: 0.6155 - val_loss: 1.4975 - val_accuracy: 0.4746
# Epoch 11/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.0652 - accuracy: 0.6298 - val_loss: 1.5068 - val_accuracy: 0.4697
# Epoch 12/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.0297 - accuracy: 0.6434 - val_loss: 1.4895 - val_accuracy: 0.4893
# Epoch 13/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.9921 - accuracy: 0.6567 - val_loss: 1.5004 - val_accuracy: 0.4918
# Epoch 14/50
# 196/196 [==============================] - 2s 13ms/step - loss: 0.9607 - accuracy: 0.6695 - val_loss: 1.5628 - val_accuracy: 0.4699
# Epoch 15/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.9251 - accuracy: 0.6824 - val_loss: 1.6301 - val_accuracy: 0.4614
# Epoch 16/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.8967 - accuracy: 0.6902 - val_loss: 1.6714 - val_accuracy: 0.4650
# Epoch 17/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.8598 - accuracy: 0.7065 - val_loss: 1.5114 - val_accuracy: 0.5034
# Epoch 18/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.8273 - accuracy: 0.7191 - val_loss: 1.5981 - val_accuracy: 0.4731
# Epoch 19/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.7985 - accuracy: 0.7285 - val_loss: 1.5881 - val_accuracy: 0.4751
# Epoch 20/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.7682 - accuracy: 0.7379 - val_loss: 1.5770 - val_accuracy: 0.4899
# Epoch 21/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.7424 - accuracy: 0.7467 - val_loss: 1.6081 - val_accuracy: 0.4870
# Epoch 22/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.7077 - accuracy: 0.7610 - val_loss: 1.6880 - val_accuracy: 0.4832
# Epoch 23/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.6826 - accuracy: 0.7701 - val_loss: 1.7335 - val_accuracy: 0.4797
# Epoch 24/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.6564 - accuracy: 0.7794 - val_loss: 1.6686 - val_accuracy: 0.4778
# Epoch 25/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.6289 - accuracy: 0.7902 - val_loss: 1.8676 - val_accuracy: 0.4560
# Epoch 26/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.5998 - accuracy: 0.8003 - val_loss: 1.6272 - val_accuracy: 0.5017
# Epoch 27/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5715 - accuracy: 0.8117 - val_loss: 1.7751 - val_accuracy: 0.4800
# Epoch 28/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5411 - accuracy: 0.8230 - val_loss: 1.8631 - val_accuracy: 0.4620
# Epoch 29/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5349 - accuracy: 0.8238 - val_loss: 1.8829 - val_accuracy: 0.4629
# Epoch 30/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5049 - accuracy: 0.8360 - val_loss: 1.8874 - val_accuracy: 0.4784
# Epoch 31/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.4804 - accuracy: 0.8427 - val_loss: 1.9653 - val_accuracy: 0.4714
# Epoch 32/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.4613 - accuracy: 0.8493 - val_loss: 1.9544 - val_accuracy: 0.4647
# Epoch 33/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.4287 - accuracy: 0.8645 - val_loss: 1.9050 - val_accuracy: 0.4716
# Epoch 34/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.4137 - accuracy: 0.8684 - val_loss: 2.0646 - val_accuracy: 0.4618
# Epoch 35/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3968 - accuracy: 0.8742 - val_loss: 2.0188 - val_accuracy: 0.4796
# Epoch 36/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3758 - accuracy: 0.8814 - val_loss: 2.2065 - val_accuracy: 0.4602
# Epoch 37/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3599 - accuracy: 0.8868 - val_loss: 2.1291 - val_accuracy: 0.4533
# Epoch 38/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.3410 - accuracy: 0.8954 - val_loss: 2.0153 - val_accuracy: 0.4728
# Epoch 39/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3258 - accuracy: 0.8986 - val_loss: 2.1425 - val_accuracy: 0.4541
# Epoch 40/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.3071 - accuracy: 0.9069 - val_loss: 2.2150 - val_accuracy: 0.4603
# Epoch 41/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.2893 - accuracy: 0.9138 - val_loss: 2.2137 - val_accuracy: 0.4667
# Epoch 42/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2767 - accuracy: 0.9168 - val_loss: 2.3069 - val_accuracy: 0.4706
# Epoch 43/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2622 - accuracy: 0.9220 - val_loss: 2.2288 - val_accuracy: 0.4674
# Epoch 44/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2473 - accuracy: 0.9277 - val_loss: 2.3397 - val_accuracy: 0.4572
# Epoch 45/50
# 196/196 [==============================] - 2s 13ms/step - loss: 0.2412 - accuracy: 0.9288 - val_loss: 2.3281 - val_accuracy: 0.4645
# Epoch 46/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2309 - accuracy: 0.9321 - val_loss: 2.3145 - val_accuracy: 0.4800
# Epoch 47/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.2134 - accuracy: 0.9399 - val_loss: 2.2541 - val_accuracy: 0.4773
# Epoch 48/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.2037 - accuracy: 0.9422 - val_loss: 2.3498 - val_accuracy: 0.4727
# Epoch 49/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.1937 - accuracy: 0.9454 - val_loss: 2.3421 - val_accuracy: 0.4687
# Epoch 50/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.1874 - accuracy: 0.9467 - val_loss: 2.5271 - val_accuracy: 0.4680

# %%
from sklearn.metrics import accuracy_score
final_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_final.argmax(axis=-1))
loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_loadback.argmax(axis=-1))

print("Accuracy of final weights: %.3f" % final_model_acc)
print("Accuracy of best weights: %.3f" % loadback_acc)
# Out:
# Accuracy of final weights: 0.468
# Accuracy of best weights: 0.492

# %%
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss", 
                             save_best_only=False)

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

model.save("final_model.h5")
model.save_weights("model_weights.h5")
# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

pred_final = model.predict(x_test)
# Load back
model = keras.models.load_model("./tmp.h5")
pred_loadback = model.predict(x_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 196/196 [==============================] - 3s 14ms/step - loss: 1.8681 - accuracy: 0.3579 - val_loss: 1.7588 - val_accuracy: 0.3812
# Epoch 2/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.5561 - accuracy: 0.4546 - val_loss: 1.6288 - val_accuracy: 0.4265
# Epoch 3/50
# 196/196 [==============================] - 2s 13ms/step - loss: 1.4512 - accuracy: 0.4922 - val_loss: 1.5629 - val_accuracy: 0.4503
# Epoch 4/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.3784 - accuracy: 0.5164 - val_loss: 1.5059 - val_accuracy: 0.4642
# Epoch 5/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.3162 - accuracy: 0.5385 - val_loss: 1.6167 - val_accuracy: 0.4449
# Epoch 6/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.2686 - accuracy: 0.5562 - val_loss: 1.4763 - val_accuracy: 0.4807
# Epoch 7/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.2155 - accuracy: 0.5762 - val_loss: 1.4747 - val_accuracy: 0.4829
# Epoch 8/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.1685 - accuracy: 0.5945 - val_loss: 1.5975 - val_accuracy: 0.4433
# Epoch 9/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.1293 - accuracy: 0.6068 - val_loss: 1.4900 - val_accuracy: 0.4820
# Epoch 10/50
# 196/196 [==============================] - 2s 11ms/step - loss: 1.0901 - accuracy: 0.6217 - val_loss: 1.4665 - val_accuracy: 0.4906
# Epoch 11/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.0476 - accuracy: 0.6378 - val_loss: 1.5610 - val_accuracy: 0.4720
# Epoch 12/50
# 196/196 [==============================] - 2s 12ms/step - loss: 1.0129 - accuracy: 0.6504 - val_loss: 1.4413 - val_accuracy: 0.5029
# Epoch 13/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.9774 - accuracy: 0.6628 - val_loss: 1.5042 - val_accuracy: 0.4777
# Epoch 14/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.9432 - accuracy: 0.6766 - val_loss: 1.5602 - val_accuracy: 0.4740
# Epoch 15/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.9047 - accuracy: 0.6897 - val_loss: 1.5311 - val_accuracy: 0.4777
# Epoch 16/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.8750 - accuracy: 0.6966 - val_loss: 1.5092 - val_accuracy: 0.4907
# Epoch 17/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.8425 - accuracy: 0.7139 - val_loss: 1.5457 - val_accuracy: 0.4910
# Epoch 18/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.8029 - accuracy: 0.7290 - val_loss: 1.5634 - val_accuracy: 0.4880
# Epoch 19/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.7790 - accuracy: 0.7354 - val_loss: 1.5678 - val_accuracy: 0.4850
# Epoch 20/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.7460 - accuracy: 0.7477 - val_loss: 1.7714 - val_accuracy: 0.4461
# Epoch 21/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.7190 - accuracy: 0.7589 - val_loss: 1.7129 - val_accuracy: 0.4649
# Epoch 22/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.6885 - accuracy: 0.7700 - val_loss: 1.6801 - val_accuracy: 0.4868
# Epoch 23/50
# 196/196 [==============================] - 2s 13ms/step - loss: 0.6608 - accuracy: 0.7792 - val_loss: 1.8728 - val_accuracy: 0.4524
# Epoch 24/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.6344 - accuracy: 0.7881 - val_loss: 1.7040 - val_accuracy: 0.4816
# Epoch 25/50
# 196/196 [==============================] - 3s 13ms/step - loss: 0.6072 - accuracy: 0.7981 - val_loss: 1.7365 - val_accuracy: 0.4765
# Epoch 26/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5734 - accuracy: 0.8106 - val_loss: 1.7432 - val_accuracy: 0.4769
# Epoch 27/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.5523 - accuracy: 0.8162 - val_loss: 1.7827 - val_accuracy: 0.4733
# Epoch 28/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5221 - accuracy: 0.8308 - val_loss: 1.8749 - val_accuracy: 0.4718
# Epoch 29/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.5028 - accuracy: 0.8364 - val_loss: 1.8599 - val_accuracy: 0.4638
# Epoch 30/50
# 196/196 [==============================] - 2s 13ms/step - loss: 0.4767 - accuracy: 0.8450 - val_loss: 1.9242 - val_accuracy: 0.4708
# Epoch 31/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.4500 - accuracy: 0.8562 - val_loss: 2.0443 - val_accuracy: 0.4654
# Epoch 32/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.4330 - accuracy: 0.8610 - val_loss: 1.9500 - val_accuracy: 0.4735
# Epoch 33/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.4159 - accuracy: 0.8679 - val_loss: 2.0232 - val_accuracy: 0.4655
# Epoch 34/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3892 - accuracy: 0.8758 - val_loss: 1.9963 - val_accuracy: 0.4588
# Epoch 35/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3635 - accuracy: 0.8873 - val_loss: 2.1810 - val_accuracy: 0.4612
# Epoch 36/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3463 - accuracy: 0.8932 - val_loss: 2.0218 - val_accuracy: 0.4731
# Epoch 37/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3300 - accuracy: 0.8998 - val_loss: 2.1465 - val_accuracy: 0.4541
# Epoch 38/50
# 196/196 [==============================] - 2s 11ms/step - loss: 0.3200 - accuracy: 0.9011 - val_loss: 2.2044 - val_accuracy: 0.4608
# Epoch 39/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2989 - accuracy: 0.9089 - val_loss: 2.2098 - val_accuracy: 0.4681
# Epoch 40/50
# 196/196 [==============================] - 2s 13ms/step - loss: 0.2843 - accuracy: 0.9131 - val_loss: 2.1746 - val_accuracy: 0.4722
# Epoch 41/50
# 196/196 [==============================] - 3s 14ms/step - loss: 0.2744 - accuracy: 0.9182 - val_loss: 2.1776 - val_accuracy: 0.4669
# Epoch 42/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2531 - accuracy: 0.9255 - val_loss: 2.3065 - val_accuracy: 0.4591
# Epoch 43/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2410 - accuracy: 0.9289 - val_loss: 2.2866 - val_accuracy: 0.4636
# Epoch 44/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2213 - accuracy: 0.9374 - val_loss: 2.3298 - val_accuracy: 0.4665
# Epoch 45/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2131 - accuracy: 0.9383 - val_loss: 2.3694 - val_accuracy: 0.4685
# Epoch 46/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.2020 - accuracy: 0.9438 - val_loss: 2.3647 - val_accuracy: 0.4695
# Epoch 47/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.1847 - accuracy: 0.9497 - val_loss: 2.3774 - val_accuracy: 0.4782
# Epoch 48/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.1779 - accuracy: 0.9514 - val_loss: 2.4298 - val_accuracy: 0.4592
# Epoch 49/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.1724 - accuracy: 0.9542 - val_loss: 2.5377 - val_accuracy: 0.4585
# Epoch 50/50
# 196/196 [==============================] - 2s 12ms/step - loss: 0.1627 - accuracy: 0.9576 - val_loss: 2.4301 - val_accuracy: 0.4712

# %%
from sklearn.metrics import accuracy_score

final_model_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_final.argmax(axis=-1))
loadback_acc = accuracy_score(y_true=y_test.argmax(axis=-1), y_pred=pred_loadback.argmax(axis=-1))

print("Accuracy of final weights: %.3f" % final_model_acc)
print("Accuracy of best weights: %.3f" % loadback_acc)
# Out:
# Accuracy of final weights: 0.471
# Accuracy of best weights: 0.471

# %% [markdown]
# ## 筆記
# ### Model checkpoint：根據狀況隨時將模型存下來，如此可以保證：
# * 假如不幸訓練意外中斷，前面的功夫不會白費。我們可以從最近的一次繼續重新開始。
# * 我們可以透過監控 validation loss 來保證所存下來的模型是在 validation set 表現最好的一個。
#
# ### save_best_only 若為 False 就是儲存最後的結果而不是最好的，所以使用 Model check point 就把 save_best_only 打開
