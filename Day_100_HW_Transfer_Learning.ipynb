# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# One-hot encode the labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
# 建立 ResNet 模型
from resnet_builder import resnet # 這是從 resnet_builder.py 中直接 import 撰寫好的 resnet 函數
model = resnet(input_shape=(32,32,3))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 16)           448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 16)           64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 16)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)           272       ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 16)           64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 16)           64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)           1088      ['activation[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)           1088      ['activation_2[0][0]']
#
#  add (Add)                   (None, 32, 32, 64)           0         ['conv2d_4[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 64)           256       ['add[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)           1040      ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 16)           64        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           1088      ['activation_5[0][0]']
#
#  add_1 (Add)                 (None, 32, 32, 64)           0         ['add[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 64)           256       ['add_1[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 16)           1040      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 16)           64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 16)           64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 64)           1088      ['activation_8[0][0]']
#
#  add_2 (Add)                 (None, 32, 32, 64)           0         ['add_1[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 64)           256       ['add_2[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)           4160      ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 64)           256       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)           36928     ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 64)           256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 128)          8320      ['add_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 128)          8320      ['activation_11[0][0]']
#
#  add_3 (Add)                 (None, 16, 16, 128)          0         ['conv2d_14[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 128)          512       ['add_3[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)           8256      ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 64)           256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 64)           36928     ['activation_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 64)           256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)          8320      ['activation_14[0][0]']
#
#  add_4 (Add)                 (None, 16, 16, 128)          0         ['add_3[0][0]',
#                                                                      'conv2d_17[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 128)          512       ['add_4[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 64)           8256      ['activation_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 64)           256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 64)           36928     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 16, 16, 64)           256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 128)          8320      ['activation_17[0][0]']
#
#  add_5 (Add)                 (None, 16, 16, 128)          0         ['add_4[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 128)          512       ['add_5[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 128)            16512     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 8, 8, 128)            512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 8, 8, 128)            512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 256)            33024     ['add_5[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 256)            33024     ['activation_20[0][0]']
#
#  add_6 (Add)                 (None, 8, 8, 256)            0         ['conv2d_24[0][0]',
#                                                                      'conv2d_23[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 256)            1024      ['add_6[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 128)            32896     ['activation_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 8, 8, 128)            512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 8, 8, 128)            512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 8, 8, 256)            33024     ['activation_23[0][0]']
#
#  add_7 (Add)                 (None, 8, 8, 256)            0         ['add_6[0][0]',
#                                                                      'conv2d_27[0][0]']
#
#  batch_normalization_24 (Ba  (None, 8, 8, 256)            1024      ['add_7[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 128)            32896     ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 8, 8, 128)            512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 8, 8, 128)            512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 256)            33024     ['activation_26[0][0]']
#
#  add_8 (Add)                 (None, 8, 8, 256)            0         ['add_7[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  batch_normalization_27 (Ba  (None, 8, 8, 256)            1024      ['add_8[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 8, 8, 256)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 1, 1, 256)            0         ['activation_27[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 256)                  0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 10)                   2570      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 849002 (3.24 MB)
# Trainable params: 843786 (3.22 MB)
# Non-trainable params: 5216 (20.38 KB)
# __________________________________________________________________________________________________

# %%
batch_size = 64
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 30 # 訓練整個資料集共 30個循環

optimizer = Adam(learning_rate=0.0001)  # You can adjust the learning rate
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stop])  # Add EarlyStopping callback to the list

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/30
# 782/782 [==============================] - 57s 43ms/step - loss: 2.2897 - accuracy: 0.3870 - val_loss: 2.0124 - val_accuracy: 0.4750
# Epoch 2/30
# 782/782 [==============================] - 30s 38ms/step - loss: 1.8971 - accuracy: 0.5184 - val_loss: 1.8211 - val_accuracy: 0.5402
# Epoch 3/30
# 782/782 [==============================] - 31s 40ms/step - loss: 1.7260 - accuracy: 0.5766 - val_loss: 1.7252 - val_accuracy: 0.5680
# Epoch 4/30
# 782/782 [==============================] - 30s 39ms/step - loss: 1.5961 - accuracy: 0.6187 - val_loss: 1.6863 - val_accuracy: 0.5848
# Epoch 5/30
# 782/782 [==============================] - 31s 39ms/step - loss: 1.4886 - accuracy: 0.6566 - val_loss: 1.6495 - val_accuracy: 0.5874
# Epoch 6/30
# 782/782 [==============================] - 31s 39ms/step - loss: 1.3957 - accuracy: 0.6870 - val_loss: 1.5901 - val_accuracy: 0.6170
# Epoch 7/30
# 782/782 [==============================] - 30s 38ms/step - loss: 1.3099 - accuracy: 0.7168 - val_loss: 1.5355 - val_accuracy: 0.6372
# Epoch 8/30
# 782/782 [==============================] - 31s 39ms/step - loss: 1.2274 - accuracy: 0.7458 - val_loss: 1.5873 - val_accuracy: 0.6258
# Epoch 9/30
# 782/782 [==============================] - 31s 39ms/step - loss: 1.1516 - accuracy: 0.7731 - val_loss: 1.7619 - val_accuracy: 0.5841
# Epoch 10/30
# 782/782 [==============================] - 30s 38ms/step - loss: 1.0760 - accuracy: 0.7955 - val_loss: 1.6150 - val_accuracy: 0.6344
# Epoch 11/30
# 782/782 [==============================] - 30s 38ms/step - loss: 1.0068 - accuracy: 0.8231 - val_loss: 1.7277 - val_accuracy: 0.6020
# Epoch 12/30
# 782/782 [==============================] - 30s 39ms/step - loss: 0.9445 - accuracy: 0.8442 - val_loss: 1.8421 - val_accuracy: 0.5951
# Epoch 13/30
# 782/782 [==============================] - 30s 38ms/step - loss: 0.8809 - accuracy: 0.8660 - val_loss: 1.8506 - val_accuracy: 0.5872
# Epoch 14/30
# 782/782 [==============================] - 30s 38ms/step - loss: 0.8223 - accuracy: 0.8861 - val_loss: 1.7211 - val_accuracy: 0.6267
# Epoch 15/30
# 782/782 [==============================] - 30s 39ms/step - loss: 0.7712 - accuracy: 0.9039 - val_loss: 1.9329 - val_accuracy: 0.6004
# Epoch 16/30
# 782/782 [==============================] - 30s 38ms/step - loss: 0.7280 - accuracy: 0.9199 - val_loss: 1.8151 - val_accuracy: 0.6303
# Epoch 17/30
# 781/782 [============================>.] - ETA: 0s - loss: 0.6894 - accuracy: 0.9311Restoring model weights from the end of the best epoch: 7.
# 782/782 [==============================] - 35s 45ms/step - loss: 0.6896 - accuracy: 0.9311 - val_loss: 1.8466 - val_accuracy: 0.6273
# Epoch 17: early stopping
# Test loss: 1.5355088710784912
# Test accuracy: 0.6371999979019165

# %%
# Plot training & validation accuracy values
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 筆記
# ### 使用範例簡化版本的 ResNet 做遷移學習，和 Day97 準確度相比其實沒有比較好，可能是因為圖像大小差異太大
